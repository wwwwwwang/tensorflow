# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
MNIST_data_folder="D:\\Users\\Madhouse\\tensorflow\\data\\mnist"
mnist=input_data.read_data_sets(MNIST_data_folder,one_hot=True)

x= tf.placeholder("float", shape=[None, 784])
y_ = tf.placeholder("float", shape=[None, 10])
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))

y = tf.nn.softmax(tf.matmul(x,W) + b)

cross_entropy = -tf.reduce_sum(y_*tf.log(y))
train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cross_entropy)

sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

for _ in range(1000):
    batch = mnist.train.next_batch(60)
    train_step.run(feed_dict={x: batch[0], y_ :batch[1]})

correct_prodiction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prodiction, "float"))

print(accuracy.eval(feed_dict={x:mnist.test.images, y_: mnist.test.labels}))
# Out:
# d:\Users\Madhouse\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Extracting D:\Users\Madhouse\tensorflow\data\mnist\train-images-idx3-ubyte.gz
# Extracting D:\Users\Madhouse\tensorflow\data\mnist\train-labels-idx1-ubyte.gz
# Extracting D:\Users\Madhouse\tensorflow\data\mnist\t10k-images-idx3-ubyte.gz
# Extracting D:\Users\Madhouse\tensorflow\data\mnist\t10k-labels-idx1-ubyte.gz
# 0.912

# %%
def weigth_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], 
                         strides=[1, 2, 2, 1], padding='SAME')

W_conv1 = weigth_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

x_image = tf.reshape(x, [-1, 28, 28, 1])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weigth_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fc1 = weigth_variable([7*7*64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weigth_variable([1024, 10])
b_fc2 = bias_variable([10])
y_conv = tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

ce = -tf.reduce_sum(y_*tf.log(y))
ts = tf.train.AdadeltaOptimizer(1e-4).minimize(ce)
cp = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
acc = tf.reduce_mean(tf.cast(cp, "float"))
sess.run(tf.global_variables_initializer())

for i in range(20000):
    batch = mnist.train.next_batch(50)
    if i%500 == 0:
        train_accuracy = acc.eval(feed_dict={
            x:batch[0], y_:batch[1], keep_prob: 1.0
        })
        print("step %d, training accuracy %g"%(i, train_accuracy))
    ts.run(feed_dict={x: batch[0], y_:batch[1], keep_prob: 0.5})

print("test accuracy %g"%acc.eval(feed_dict={
    x: mnist.test.images, y_: mnist.test.labels, keep_prob:1.0
}))
# Out:
# step 0, training accuracy 0.06
# step 500, training accuracy 0.06
# step 1000, training accuracy 0.1
# step 1500, training accuracy 0.1
# step 2000, training accuracy 0.04
# step 2500, training accuracy 0.14
# step 3000, training accuracy 0.12
# step 3500, training accuracy 0.14
# step 4000, training accuracy 0.08
# step 4500, training accuracy 0.16
# step 5000, training accuracy 0.16
# step 5500, training accuracy 0.14
# step 6000, training accuracy 0.2
# step 6500, training accuracy 0.14
# step 7000, training accuracy 0.16
# step 7500, training accuracy 0.1
# step 8000, training accuracy 0.06
# step 8500, training accuracy 0.2
# step 9000, training accuracy 0.12
# step 9500, training accuracy 0.08
# step 10000, training accuracy 0.06
# step 10500, training accuracy 0.08
# step 11000, training accuracy 0.1
# step 11500, training accuracy 0.02
# step 12000, training accuracy 0.12
# step 12500, training accuracy 0.18
# step 13000, training accuracy 0.12
# step 13500, training accuracy 0.08
# step 14000, training accuracy 0.12
# step 14500, training accuracy 0.16
# step 15000, training accuracy 0.04
# step 15500, training accuracy 0.12
# step 16000, training accuracy 0.14
# step 16500, training accuracy 0.16
# step 17000, training accuracy 0.18
# step 17500, training accuracy 0.18
# step 18000, training accuracy 0.1
# step 18500, training accuracy 0.08
# step 19000, training accuracy 0.1
# step 19500, training accuracy 0.12
# test accuracy 0.0961
